# %%
# получение информации c api
import json
import urllib.request
def get_data(username, variable):
    token = '4a7672e60547c41c5b62c353d539ee0117f26191' # токен
    url = 'https://api.github.com/users/{}/{}?page=1?access_token={}&per_page=100'.format(username, variable, token) # variable - переменная для разных адресов (repos, followers)
    
    response = urllib.request.urlopen(url)  # посылаем серверу запрос и достаем ответ
    text = response.read().decode('utf-8')  # читаем ответ в строку
    data = json.loads(text) # превращаем джейсон-строку в объекты питона
    return data

# %%
# 1. репозитории и их описания
def getting_repos(user):
    d = {}
    data = get_data(user, 'repos')
    for i in data:
        d[i['name']] = i['description'] # словарь, где ключ - репозиторий, а значение - описание
    print('\n')
    print('Вот список его репозиториев:')
    for key, value in d.items():
        print('{}: {}'.format(key, value))

# %%
# 2. языки и репозитории
import collections
def getting_languages(user):
    s = []
    data = get_data(user, 'repos')
    for i in data:
        if i['language'] != None: # выкидываем репозитории, написанные на языке 'None'
            s.append(i['language']) # список языков
#     print(s) - проверка
    counter = collections.Counter(s)  # словарь, где язык - ключ, количество репозиториев, написанных на этом языке - значение
    print('\n')
    print('Языки, на которых пишет пользователь {}: '.format(user), end='')
#     for key in counter.keys(): # печатаем языки
    print(', '.join(counter.keys()), end='')
    print('.', sep='')
    print('\n')
    for key, value in counter.items(): # печатаем языки и количество репозиториев        
        print('Количество репозиториев, написанных на языке {}: {}. '.format(key, value))

# %%
# 3. сравнение числа репозиториев
def comparing_repos(users):
    d = {} # сделаем словарь, где ключ - имя пользователя, значение - количество репозиториев
    print('\n')
    print ('Из списка ', end='')
    for user in users:
        print('{}, '.format(user), end='')
        data = get_data(user, 'repos')
        d[user] = len(data) # словарь, где ключи - пользователи, значения - количество репозиториев
#     for key, value in d.items():
#         print(key, value) - это была проверка
    max = sorted(d, key=d.get, reverse=True) # здесь сортируем ключи (пользователей) по возрастанию количества репозиториев
    print('больше всего репозиториев у пользователя {}.'.format(max[0]))# у первого человека в списке больше всего репозиториев

# %%
# 4. какой язык самый распространенный
import collections
def counting_languages(users):
    s = []
    print('\n')
    print('Самый популярный язык среди пользователей из списка ', end='')
    for user in users:
        data = get_data(user, 'repos')
        for i in data:
            s.append(i['language']) # список из языков, которые использует каждый пользователь в каждом репозитории   
    counter = collections.Counter(s) # словарь, где ключи - языки, значения - сколько раз они используются
#     for key, value in counter.items():
#         print(key, ':', value) - это была проверка
    max = sorted(counter, key=counter.get, reverse=True) # сортировка языков по возрастанию использования
    print(', '.join(users), end='')
    print(' -- {}.'.format(max[0])) # первый язык - самый частотный

# %%
# 5. у кого больше подписчиков
def counting_followers(users):
    d = {}
    for user in users:
        data = get_data(user, 'followers')
        d[user] = len(data) # словарь,где ключи - пользователи, значения - количество подписчиков
#     for key, value in d.items():
#         print(key, value) - это была проверка
    max = sorted(d, key=d.get, reverse=True) # сортировка пользователей по чилу подписчиков
    print('\n')
    print('Больше всего подписчиков у пользователя {}.'.format(max[0]))

# %%
# главная функция
users_list = ['elmiram', 'maryszmary', 'lizaku', 'nevmenandr', 'ancatmara', 'roctbb', 'akutuzov', 'agricolamz', 'lehkost', 'kylepjohnson', 'mikekestemont', 'demidovakatya', 'shwars', 'JelteF', 'timgraham', 'arogozhnikov', 'jasny', 'bcongdon', 'whyisjake', 'gvanrossum'] # заданный список пользователей
def main(users_list):
#     users = users_consequence.split(', ')
    users = users_list
    user = input('Введите имя пользователя, о котором хотели бы узнать побольше: ') # ввод пользователя
    if not user in users: # если такого пользователя нет в списке
        print('Такого пользователя нет в списке, повторите попытку!')
    else:
        print('\n')
        print('Вы выбрали пользователя {}.'.format(user))#
        getting_repos(user)
        getting_languages(user)
        comparing_repos(users)
        counting_languages(users)
        counting_followers(users)
# elmiram, maryszmary, lizaku, nevmenandr, ancatmara, roctbb, akutuzov, agricolamz, lehkost, kylepjohnson, mikekestemont, demidovakatya, shwars, JelteF, timgraham, arogozhnikov, jasny, bcongdon, whyisjake, gvanrossum
    
if __name__ == '__main__':
    main(users_list)
# Out:
# Введите имя пользователя, о котором хотели бы узнать побольше: whyisjake
#
#
# Вы выбрали пользователя whyisjake.
#
#
# Вот список его репозиториев:
# alpha-brand-lab: Collection of static sites and pages that live within the Alpha collection
# altrablog: None
# amp-wp: WordPress plugin for adding AMP support
# arduino_robot: Build a mind controlled Arduino Robot
# Autism-Spectrum-Quotient: Psychologist Simon Baron-Cohen and his colleagues at Cambridge’s Autism Research Centre have created the Autism-Spectrum Quotient, or AQ, as a measure of the extent of autistic traits in adults. In the first major trial using the test, the average score in the control group was 16.4. Eighty percent of those diagnosed with autism or a related disorder scored 32 or higher. The test is not a means for making a diagnosis, however, and many who score above 32 and even meet the diagnostic criteria for mild autism or Asperger’s report no difficulty functioning in their everyday lives.
# awesome-geek-podcasts: A curated list of podcasts we like to listen to
# Backyard-Lens: Radiant Poetry
# baker: The HTML5 ebook framework to publish interactive books & magazines on iPad & iPhone using simply open web standards
# Barebone-Wordpress-Metabox: Add extra meta information the easy way with a meta box in your wordpress posts.
# Blink: BI Dashboard on Arduino
# Bootstrap: The Bootstrap Book
# bootstrap-1: Sleek, intuitive, and powerful front-end framework for faster and easier web development.
# bootstrapped: Bootstrapped WordPress Theme
# CES-Letter: HTML version of the CES Letter, by Jeremy Runnels.
# Co-Authors-Plus: Multiple bylines and Guest Authors for WordPress
# contextly-plugin-wordpress: Contextly Wordpress Plugin
# DANGER-: None
# dash: Simple function for adding Dash Analytics to you site. Could be used on the front end showing trending, popular, and most shared posts.
# debug-bar-post-meta: Adds a panel to debug bar that displays all post meta.
# developer: In your WordPress, developing locally
# disqus-wordpress: WordPress integration for DISQUS
# dotfiles: None
# Drafts-for-Friends: None
# Employee-Portfolio: None
# fieldmanager-demos: A WordPress Plugin used for demonstrating Fieldmanager
# flying-goat: Flying Goat Coffee WordPress theme
# Forest-Group: Sonoma County Forest Conservation Work Group
# Front-end-Developer-Interview-Questions: A list of questions you can use to help interview potential candidates for a front-end development position.
# gear: None
# get_image: Get all of the images for the signs for Maker Faire.
# Gravity-Forms-Helper: Easily access entry data from Gravity Forms using a handy shortcode.
# Greyhound: Greyhound project for #videohack
# Hanks-Family-Recipes: WordPress theme for the Hanks Family Recipes site
# JakeSpurlock.com: Child Theme, based on 2013
# JSbooks: Open source javascript books compilation
# lazyload-liveblog-entries: WordPress plugin to lazyload Liveblog entries
# Luna: Liveblog with Socket.io and Tumblr
# maker-camp: None
# maker-faire-signs: None
# makered-2012: The Maker Education Initiative WordPress Theme
# makerspace: Makerspace WordPress theme
# makerspace-plugin: Functions for Makerspace
# Mentor-Makerspace: WordPress Theme for mentor.makerspace.com
# new-tab-always: Always open WordPress links in a new tab
# newsnerdery.org: None
# oatv: OATV's website
# Order-Bender: A small WordPress plugin that allows you to set the primary category for a post. Works in conjunction with Breadcrumb NavXT to specify a category hiearchy.
# phpjs: php.js implements PHP functions in JavaScript
# Podtrac-and-Powerpress: None
# Podtrac-with-Seriously-Simple-Podcasting: If you wanted to add Podtrac support to your site, in conjunction with Seriously Simple Podcasting, this is the plugin that will do it.
# Projects-Importer: Creates a WordPress WXR File From Make:Projects
# Projects-Step-Editor: Projects Step Editor
# ratchet: Prototype iPhone apps with simple HTML, CSS, and JS components.
# Ready-to-Publish: Simple WordPress plugin that adds a step to prevent posts from accidental publishing.
# remove-markdown: Strip Markdown stuff from text
# restful-hello-dolly: A more RESTful Hello Dolly Plugin
# Seriously-Simple-Podcasting: WordPress podcasting the way it's meant to be. No mess, no fuss - just you and your content taking over the world.
# Shortcake: Shortcake makes using WordPress shortcodes a piece of cake.
# Simple-Instant-Articles-for-Facebook: Add support for Facebook Instant Articles to your WordPress site.
# sixteenwomen.com: Site of the SixteenWomen.com podcast.
# SMD-Shield: Arduino SMD Shield
# smrt: SMRTDSGN.com WordPress Theme
# Social-Stats: Tool for getting the social stats from Facebook, Twitter, and G+.
# socialrestraint.club: None
# sunstone: Parser for building the Sunstone RSS feeds
# Sunstone-Podcast-Importer: WordPress plugin to import all of the podcasts into the Sunstone archives.
# Sunstone-Terms: NLP from Google, with the WordPress plugin
# tacofancy: community-driven taco repo. stars stars stars.
# term-debt-consolidator: A WordPress plugin that suggests tags for consolidation.
# Trump-Tweet-Investigator: Handy Chrome extension to investigate the claims of Trump's Tweets
# vip-quickstart: Quickstart your WordPress.com VIP development!
# warmachine: Simple Node/Backbone/Express app for Warmachine
# whyisjake.github.com: Jekyll Powered Github Blog
# WiiUTutorial: None
# wimp: Bootstrap WIMP Meetup
# Wired-Express: Playing around with Node and the Wired JSON API.
# wired-wpcom-thumbnail-editor: WIRED's WordPress.com Thumbnail Editor / Edit thumbs without Jetpack
# WordPress: WordPress, Git-ified. Synced via SVN every 15 minutes, including branches and tags! This repository is just a mirror of the WordPress subversion repository. Please do not send pull requests. Submit patches to http://core.trac.wordpress.org/ instead.
# wordpress-database-switch: Bash script to quickly swap the active WordPress database.
# wordpress-documentcloud: Embed DocumentCloud documents that won't be eaten by the visual editor
# wordpress-listening-plugin: None
# WordPress-X-Mullet: Business in front, and party in the back. Special header for WordPress.
# WP-API: A JSON-based REST API for WordPress
# wp-cli.github.com: wp-cli.org website
# wp-parsely: The official WordPress plugin for Parse.ly's Dash - makes it a snap to add the required tracking code to enable Dash on your WordPress site.
# wpsf: Bootstrap - Responsive Theme Design Talk for the WordPress SF Meetup Group
# YouTube-to-WordPress-XML: Generate WordPress XML exports from YouTube playlists.
#
#
# Языки, на которых пишет пользователь whyisjake: CSS, PHP, JavaScript, Objective-C, Arduino, HTML, Shell, Ruby.
#
#
# Количество репозиториев, написанных на языке CSS: 5.
# Количество репозиториев, написанных на языке PHP: 39.
# Количество репозиториев, написанных на языке JavaScript: 23.
# Количество репозиториев, написанных на языке Objective-C: 1.
# Количество репозиториев, написанных на языке Arduino: 2.
# Количество репозиториев, написанных на языке HTML: 1.
# Количество репозиториев, написанных на языке Shell: 3.
# Количество репозиториев, написанных на языке Ruby: 1.
#
#
# Из списка elmiram, maryszmary, lizaku, nevmenandr, ancatmara, roctbb, akutuzov, agricolamz, lehkost, kylepjohnson, mikekestemont, demidovakatya, shwars, JelteF, timgraham, arogozhnikov, jasny, bcongdon, whyisjake, gvanrossum, больше всего репозиториев у пользователя JelteF.
#
#
# Самый популярный язык среди пользователей из списка
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-99-6be5726fd6f4> in <module>()
#      18
#      19 if __name__ == '__main__':
# ---> 20     main(users_list)
#
# <ipython-input-99-6be5726fd6f4> in main(users_list)
#      13         getting_languages(user)
#      14         comparing_repos(users)
# ---> 15         counting_languages(users)
#      16         counting_followers(users)
#      17 # elmiram, maryszmary, lizaku, nevmenandr, ancatmara, roctbb, akutuzov, agricolamz, lehkost, kylepjohnson, mikekestemont, demidovakatya, shwars, JelteF, timgraham, arogozhnikov, jasny, bcongdon, whyisjake, gvanrossum
#
# <ipython-input-95-7b2c8f52b657> in counting_languages(users)
#       6     print('Самый популярный язык среди пользователей из списка ', end='')
#       7     for user in users:
# ----> 8         data = get_data(user, 'repos')
#       9         for i in data:
#      10             s.append(i['language']) # список из языков, которые использует каждый пользователь в каждом репозитории
#
# <ipython-input-91-9eccabeef2f0> in get_data(username, variable)
#       6     url = 'https://api.github.com/users/{}/{}?page=1?access_token={}&per_page=100'.format(username, variable, token) # variable - переменная для разных адресов (repos, followers)
#       7
# ----> 8     response = urllib.request.urlopen(url)  # посылаем серверу запрос и достаем ответ
#       9     text = response.read().decode('utf-8')  # читаем ответ в строку
#      10     data = json.loads(text) # превращаем джейсон-строку в объекты питона
#
# c:\users\annap\miniconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# c:\users\annap\miniconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# c:\users\annap\miniconda3\lib\urllib\request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# c:\users\annap\miniconda3\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# c:\users\annap\miniconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# c:\users\annap\miniconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden

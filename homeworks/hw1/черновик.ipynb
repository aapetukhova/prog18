# %%
import random
#reading the file (with words)
def file(filename):
    with open(filename, encoding='utf-8') as f:
        words = []
        for line in f:
            words.append(line.strip('\n'))    
    return words

# выбор темы    
def themes():
    print('1 - Динозавры')
    print('2 - Звезды')
    print('3 - Фараоны Древнего Египта')
    theme = input('Выберите тему: ')
    return theme

# рандомайзер слов темы
def random(theme):
    import random
    l = []
    if theme == '1':
        l = file('dino.txt')
    elif theme == '2':
        l = file('stars.txt')
    elif theme == '3':
        l = file('skull.txt')
    puzzle = random.choice(l)
    return puzzle

# собственно игра
def game():
    used_letters = []
    print('У Вас есть 10 попыток, чтобы угадать слово из', len(puzzle), 'букв')
#     word = '_ '*len(puzzle)
#     print(word)
    guess_taken = 0
    while guess_taken < 9:
        print('Введите букву: ')
        guess = input().lower()
        if not guess.isalpha():
            print('Это не буква!!!')
        elif guess in used_letters:
            print('Вы уже использовали эту букву!!!')
        else:
            used_letters.append(guess)
            if guess in puzzle:
                print('Угадали!')
#                 печать букв и черточек
#                 s = list(word)
                for i in range (0, len(puzzle)):
                    if puzzle[i] == guess:
                        s[i] = guess
                print(''.join(s))  
                if word == puzzle:
                    print('Вы победили!')
#                     while c not in used_letters:                 
#                     	print('_ ', end='')
#                     print(c)
#                 if not '_ ' in 
            else:
                print('Такой буквы нет!!!')
                guess_taken += 1
                img(guess_taken)
                if guess_taken == 9:
                    print('Вы проиграли!!!')
                
                
                

# изображение будет словарем, тогда печать будет по ключам
    man = {}
    man[0] = ['_']
    man[1] = ['__']
    man[2] = ['___', '   |']
    man[3] = ['___', '   |', '   O']
    man[4] = ['___', '   |', '   O', '-']
    man[5] = ['___', '   |', '   O', '-|']
    man[6] = ['___', '   |', '   O', '-|-']
    man[7] = ['___', '   |', '   O', '-|-', '  /']
    man[8] = ['___', '   |', '   O', '-|-', '  / \\']
    
def img(a):
    if key in man.keys() == a:
        print(man[value])
        
        

    
#     if a == 0:
#         print('\n'*2)
#         print(' /')
#         print('Осталось 5 попыток')
#     if a == 1:
#         print('\n'*2)
#         print(' / \\')
#         print('Осталось 4 попытки')
#     if a == 2:
#         print('\n')
#         print(' -')
#         print(' / \\')
#         print('Осталось 3 попытки')
#     if a == 3:
#         print('\n')
#         print(' -|')
#         print(' / \\')
#         print('Осталось 2 попытки')
#     if a == 4:
#         print('\n')
#         print(' -|-')
#         print(' / \\')
#         print('Осталась 1 попытка')
#     if a == 5:
#         print('  X')
#         print(' -|-')
#         print(' / \\')
#         print('Вы проиграли')
        
    
    

        
    
    
def main():
#     count(file('stars.txt'))
    game(random(themes()))
    

if __name__ == '__main__':
    main()
    
    # def evaluator(puzzle, result, missed):
#     guess = input() 
#     if (guess in result) or (guess in missed) or not guess.isalpha():
#         return None, False
#     i = 0
#     right = guess in puzzle
#     for symbol in puzzle:
#         if symbol == guess:
#             result[i] = symbol
#         i += 1
#     return guess, right                    
#     #условие, печать черточек
#     success = False
#     i = 0
#     missed = []
#     while i < 10:
#         print('Введите букву: ')
#         guess, right = evaluator(puzzle, result, missed)
#         if guess == None:
#             print('Этот символ уже был введен')
#             continue
#         print(''.join(result))
#         if result == puzzle:
#             print('Вы победили!')
#             success = True
#             break
#         if not right:
#             missed.append(guess)
#             i += 1
#     if not success:
#         print('Вы проиграли!!!')
            
# #     на каждую букву: ввод буквы, проверка, печать
#     for i in range(0, len(puzzle)):
#         print('Введите букву: ')
#         letter = input()
#         m = 0
#         if letter.isalpha():
# #       если это буква, смотрим все буквы в слове
#             for i in range (0, len(puzzle)):
# #               если ввод совпадает, печать
#                 if letter == puzzle[i]:

#                     break
# #               если не совпадает
#                 else:
#                     print('Такой буквы в слове нет!!!')
#                     m += 1

#         else:
#             print('Это не буква!!!')
            
# ___    
#   |
#   O   
#  -|-
#  / \
# Out:
# 1 - Динозавры
# 2 - Звезды
# 3 - Фараоны Древнего Египта
# Выберите тему: 1
# У Вас есть 10 попыток, чтобы угадать слово из 16 букв
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# Введите букву:
# р
# Угадали!
# _ _ _р_ _ р _ _р_ _ _ _ _ _ _ _
# Введите букву:
# а
# Угадали!
# а _ _ _а_ _а_ _ _ _ _ _ _ _ _ _
# Введите букву:
# в
# Такой буквы нет!!!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1bd7d46d2187> in <module>()
#     129
#     130 if __name__ == '__main__':
# --> 131     main()
#     132
#     133     # def evaluator(puzzle, result, missed):
#
# <ipython-input-1-1bd7d46d2187> in main()
#     125 def main():
#     126 #     count(file('stars.txt'))
# --> 127     game(random(themes()))
#     128
#     129
#
# <ipython-input-1-1bd7d46d2187> in game(puzzle)
#      62                 print('Такой буквы нет!!!')
#      63                 guess_taken += 1
# ...

# %%
import random
from typing import List
used_letters = []
word = []
#reading the file (with words)
def file(filename):
    with open(filename, encoding='utf-8') as f:
        words = []
        for line in f:
            words.append(line.strip('\n'))    
    return words

# выбор темы    
def themes():
    print('1 - Динозавры')
    print('2 - Звезды')
    print('3 - Фараоны Древнего Египта')
    theme = input('Выберите тему: ')
    return theme

# рандомайзер слов темы
def random(theme):

    l = []
    if theme == '1':
        l = file('dino.txt')
    elif theme == '2':
        l = file('stars.txt')
    elif theme == '3':
        l = file('skull.txt')
    return l

def random():
    
puzzle = random.choice(random(themes()))

def guess_out(letters: List):
    print('Вот Вам слово, угадывайте: {0}'.format(' '.join(letters)))
    
def attempts_taken_out(current: int, total: int):
    print('У Вас осталось {0}/{1}.'.format(current, total))

def character_hide():
    for c in puzzle:
        word.append('_')
    print('В слове ', len(puzzle), 'букв')
    guess_out(word)
    
def game():
    atttempts_taken = 1
    attempts_total = 10
    attempts_taken_out(attempts_taken, attempts_total)
    
    while attempts_taken < attempts_total:
        guess = input('Введите букву: ').lower()
        if not guess.isalpha():
            print('Введите букву!')
        elif guess in used_letters:
            print('Вы уже вводили эту букву!')
        else:
            used_letters.append(guess)
            if guess in puzzle:
                print('Угадали!')
                for i in range(0, len(puzzle)):
                    if puzzle[i] == guess:
                        word[i] = guess
                guess_out(word)
                attempts_taken_out(attempts_taken, attempts_total)
                if not '_' in word:
                    print('Победа!')
                    break
            else:
                print('Такой буквы нет!!!')
                attempts_taken += 1
                attempts_taken_out(attempts_taken, attempts_total)
                if attempts_taken == 10:
                    print('Вы проиграли!!!')
                    

                    
                    
def main():
    character_hide()
    game()
                    
                    
if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-a75bfc9e09bd> in <module>()
#      31     return l
#      32
# ---> 33 puzzle = random.choice(random(themes()))
#      34
#      35 def guess_out(letters: List):
#
# AttributeError: 'function' object has no attribute 'choice'

# %%
# заново



# потому что очень непонятно

# сначала нужно прочитать слова из файла
# потом вывести темы и в зависимости от выбора темы выбрать слово из списка

# ввод количество попыток
# ввод символа, проверка на букву, уже введенную букву
# печать черточек: отдельная функция
#     на каждый символ слова печатай черточку
#     это список
    
    
    
# символ - буква:
#     есть ли она в слове, если есть, то замена черточки на букву, сохранение этого слова, дальше
#     если нет - начало отсчета попыток, вывод человечка
    
# от чего будут зависеть функции?


import random
#reading the file (with words)
def file(filename):
    with open(filename, encoding='utf-8') as f:
        words = []
        for line in f:
            words.append(line.strip('\n'))    
    return words

# выбор темы    
def themes():
    print('1 - Динозавры')
    print('2 - Звезды')
    print('3 - Фараоны Древнего Египта')
    theme = input('Выберите тему: ')
    return theme

# рандомайзер слов темы
def random(theme):
    import random
    l = []
    if theme == '1':
        l = file('dino.txt')
    elif theme == '2':
        l = file('stars.txt')
    elif theme == '3':
        l = file('skull.txt')
    puzzle = random.choice(l)
    return puzzle

#каждую букву в слове заменяет на черточку, при этом все это в виде списка, чтобы сохранялись уже введенные буквы
def character_hide():
    for c in puzzle:
        word.append('_')
    print('В слове ', len(puzzle), 'букв')
    guess_out(word)

def guess_out(letters: str):
    print('Слово: {0}'.format(' '.join(letters)))
    
# игра
def game():
    atttempts_taken = 0
#     attempts_total = 10
#     attempts_taken_out(attempts_taken, attempts_total)
    print('')
    while attempts_taken < 9:
        guess = input('Введите букву: ').lower()
        if not guess.isalpha():
            print('Введите букву!')
        elif guess in used_letters:
            print('Вы уже вводили эту букву!')
        else:
            used_letters.append(guess)
            if guess in puzzle:
                print('Угадали!')
                for i in range(0, len(puzzle)):
                    if puzzle[i] == guess:
                        word[i] = guess
                guess_out(word)
                attempts_taken_out(attempts_taken, attempts_total)
                if not '_' in word:
                    print('Победа!')
                    break
            else:
                print('Такой буквы нет!!!')
                attempts_taken += 1
                attempts_taken_out(attempts_taken, attempts_total)
                if attempts_taken == 10:
                    print('Вы проиграли!!!')

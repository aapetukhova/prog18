# %%
import urllib.request
from bs4 import BeautifulSoup
import os
import re

# Функция преобразовывает буквенный месяц
# (дата на сайте указана в формате ДД МЕСЯЦ (ГГГГ)) в числовой

def monthToDigit(month):
    if month == 'января':
        monthDigit = '01'

    elif month == 'февраля':
        monthDigit = '02'

    elif month == 'марта':
        monthDigit = '03'

    elif month == 'апреля':
        monthDigit = '04'

    elif month == 'мая':
        monthDigit = '05'

    elif month == 'июня':
        monthDigit = '06'

    elif month == 'июля':
        monthDigit = '07'

    elif month == 'августа':
        monthDigit = '08'

    elif month == 'сентября':
        monthDigit = '09'

    elif month == 'октября':
        monthDigit = '10'

    elif month == 'ноября':
        monthDigit = '11'

    elif month == 'декабря':
        monthDigit = '12'

    return monthDigit

# %%
# Функция поиска (мета)данных по тэгам


def meta(pageUrl):
    try:
        d = {}
        page = urllib.request.urlopen(pageUrl)
        text = page.read().decode('utf-8')
        soup = BeautifulSoup(text, 'html.parser')
        # поиск заголовка
        d['header'] = soup.find('div', {'class': 'f26'}).get_text()
        # поиск текста статьи
        tagText = soup.find('div', {'id': 'material_text'}).get_text()
        # чистим статью от тэгов html, которые попали в div
        woN = re.sub(r'\n', '', tagText)
        woR = re.sub(r'\r', '', woN)
        woT = re.sub(r'\t', '', woR)
        # чистый текст
        d['text'] = woT.strip()
        # здесь содержится информация об авторе и дате
        footer = soup.find('div', {'id': 'vnizu_a_n_v'})
        children = footer.findChildren('div')
        # строка с именем автора
        authorLine = str(children[0])
        # строка с датой
        dateLine = str(children[1])
        # поиск автора
        author = re.search(
            'Автор: (.*?)(((\.)|(\,))(.*?))?</div>', authorLine)
        linkAuthor = re.search(
            '<a.+?></a>', authorLine)   
        if author and not linkAuthor:
            d['author'] = author.group(1)
        else:
            d['author'] = 'None'
        # поиск даты
        date = re.search('Время: (.*?)</div>', dateLine)
        if date:
            # выделяем год
            year = re.search('[а-я]*? (....) г', date.group(1))
            if year:
                d['year'] = year.group(1)
            # но иногда его нет...
            else:
                d['year'] = 'None'
            # выделяем месяц
            month = re.search('.. ([а-я]*)[ ]*?(.... г)?', date.group(1))
            if month:
                digitMonth = month.group(1)
                d['month'] = monthToDigit(digitMonth.strip())
            # выделяем день
            day = re.search('(..) [а-я]*[ ]*?(.... г)?', date.group(1))
            if day:
                d['day'] = day.group(1)

            return d
    # на случай, если страница сломана
    except:
        print('Error at', pageUrl)

# %%
# собственно краулер


def crowler():
    # ссылка на странички
    commonUrl = 'http://www.vecherniy.com/wall?id='
    # огромный словарь всех статей с сайта
    # ключ - номер статьи на сайте,
    # значения - словарь с мета-данными каждой статьи
    bigD = {}
    # считаем статьи
#     изменила количество страниц
    for i in range(1, 1102):
        pageUrl = commonUrl + str(i)
        d = meta(pageUrl)
        if d:
            # если все прошло успешно, и ссылка не сломана -
            # добавляем в мета-данные адрес
            d['url'] = pageUrl
            bigD[i] = d
        # если нет - ничего не делаем
        else:
            pass
    return bigD

# %%
# Функция представления даты в формате ДД.ММ.ГГГГ


def date_dots(dictionary):
    goodDate = dictionary['day'] + '.' + dictionary['month'] + '.' + dictionary['year']
    return goodDate

# %%
# Функция разбиения текста на предложения и на строки



def break_maker(text):
    dots = re.sub('\. ', '.\\n', text)
    exclamations = re.sub('\! ', '!\\n', dots)
    questions = re.sub('\? ', '?\\n', exclamations)
    return questions

# %%
# Функция подсчета статей в папке год\месяц


def enum_art(bigD):
    y = bigD[1]['year']
    m = bigD[1]['month']
    i = 0
    for key, value in bigD.items():
        if bigD[key]['year'] == y and bigD[key]['month'] == m:
            i += 1
            bigD[key]['ordinal'] = i
        else:
            y = bigD[key]['year']
            m = bigD[key]['month']
            i = 1
            bigD[key]['ordinal'] = i
    return bigD

# %%
# Функция создает файлы mystem и папки для них
# root - корень папки, т.к. у нас 2 папки с mystem-файлами,
# bigD - большой словарь со всеми статьями,
# abbr - тип файла (.txt или .xml),
# special - пометка для .xml-файлов



def mystemization(root, bigD, abbr, special):
    # местоположение mystem
#     изменила путь к mystem
    way = r'C:\Users\annap\mystem.exe'
    # функции mystem
    settings = ' -cdli --eng-gr '
    for key, values in bigD.items():
        mystemPath = root
        # создаем папку с годом, месяцем, туда записываем статьи
        dirPYMPath = os.path.join(root, bigD[key]['year'], bigD[key]['month'])
        # для первой папки год\месяц
        if not os.path.exists(dirPYMPath):
            os.makedirs(dirPYMPath)
        # каждое предложение с новой строчки
        text = break_maker(bigD[key]['text'])
        # временный файл txt, откуда мы будем брать текст для разметки
        filename = 'input' + str(bigD[key]['ordinal']) + '.txt'
        filepath = os.path.join(dirPYMPath, filename)
        # создаем новый файл и записываем туда текст статьи
        with open(filepath, 'x', encoding='utf-8') as f:
            f.write(text)
        # майстемизация в деле:
        # временный файл
        inp = filepath
        # перманентный файл: articleN.xml
        outfilename = 'article' + str(bigD[key]['ordinal']) + abbr
        # путь к файлу в папке mystem
        out = os.path.join(dirPYMPath, outfilename)
        os.system(way + settings + special + inp + ' ' + out)
        # удаляем временный файл
        os.remove(filepath)

# %%
# запись файлa plain-text


def write_article(d, dirpath):
    # файл articleN.txt
    filename = 'article' + str(d['ordinal']) + '.txt'
    # путь к файлу в папке
    filepath = os.path.join(dirpath, filename)
# добавляем путь к неразмеченному тексту - мета-данные
    d['path'] = filepath
    with open(d['path'], 'x', encoding='utf-8') as f:
        # сначала мета-информация...
        f.write('@au {}'.format(d['author']))
        f.write('\n')
        f.write('@ti {}'.format(d['header']))
        f.write('\n')
        f.write('@da {}'.format(date_dots(d)))
        f.write('\n')
        f.write('@topic {}'.format('None'))
        f.write('\n')
        f.write('@url {}'.format(d['url']))
        f.write('\n')
        # ...потом текст
        f.write(d['text'])

    return d

# %%
# Функция создает папки для неразмеченного текста


def plain_folders(bigD):
    # у нас есть метаданные: создаем папку с годом, месяцем
    # записываем туда статьи
    for key, values in bigD.items():
        # путь до корневой папки
        plainPath = r'Y\plain'
        dirPYMPath = os.path.join(
            plainPath, bigD[key]['year'], bigD[key]['month'])
        if not os.path.exists(dirPYMPath):
            os.makedirs(dirPYMPath)
        # запись в файл
        bigD[key] = write_article(bigD[key], dirPYMPath)

    return bigD

# %%
# Функция создает файл для метаданных в формате csv


def meta_csv(bigD):
    filepath = r'YV\metadata.csv'
    # записываем в файл
    with open(filepath, "x", encoding="utf-8") as f:
        for key, values in bigD.items():
            f.write(
                '{}\t{}\t{}\t{}\tпублицистика\tNone\tнейтральный\tн-возраст\tн-уровень\tгородская\t{}\t"Якутск вечерний"\t{}\tгазета\tРоссия\tРеспублика Саха (Якутия)\tru'
                .format(bigD[key]['path'], bigD[key]['author'],
                bigD[key]['header'], date_dots(bigD[key]),
                bigD[key]['url'], bigD[key]['year']))
            f.write('\n')

# %%
def main():
    a = enum_art(crowler())
    meta_csv(plain_folders(a))
    mystemization(
        r'YV\mystem-xml', a, '.xml', '--format xml ')
    mystemization(r'YV\mystem-plain', a, '.txt', '')

if __name__ == '__main__':
    main()
# Out:
# Error at http://www.vecherniy.com/wall?id=524
# Error at http://www.vecherniy.com/wall?id=530
# Error at http://www.vecherniy.com/wall?id=532
# Error at http://www.vecherniy.com/wall?id=544
# Error at http://www.vecherniy.com/wall?id=556
# Error at http://www.vecherniy.com/wall?id=563
# Error at http://www.vecherniy.com/wall?id=566
# Error at http://www.vecherniy.com/wall?id=567
# Error at http://www.vecherniy.com/wall?id=568
# Error at http://www.vecherniy.com/wall?id=569
# Error at http://www.vecherniy.com/wall?id=570
# Error at http://www.vecherniy.com/wall?id=571
# Error at http://www.vecherniy.com/wall?id=572
# Error at http://www.vecherniy.com/wall?id=573
# Error at http://www.vecherniy.com/wall?id=574
# Error at http://www.vecherniy.com/wall?id=575
# Error at http://www.vecherniy.com/wall?id=576
# Error at http://www.vecherniy.com/wall?id=577
# Error at http://www.vecherniy.com/wall?id=578
# Error at http://www.vecherniy.com/wall?id=579
# Error at http://www.vecherniy.com/wall?id=580
# Error at http://www.vecherniy.com/wall?id=581
# Error at http://www.vecherniy.com/wall?id=582
# Error at http://www.vecherniy.com/wall?id=583
# Error at http://www.vecherniy.com/wall?id=584
# Error at http://www.vecherniy.com/wall?id=585
# Error at http://www.vecherniy.com/wall?id=586
# Error at http://www.vecherniy.com/wall?id=587
# Error at http://www.vecherniy.com/wall?id=588
# Error at http://www.vecherniy.com/wall?id=589
# Error at http://www.vecherniy.com/wall?id=590
# Error at http://www.vecherniy.com/wall?id=591
# Error at http://www.vecherniy.com/wall?id=592
# Error at http://www.vecherniy.com/wall?id=593
# Error at http://www.vecherniy.com/wall?id=594
# Error at http://www.vecherniy.com/wall?id=595
# Error at http://www.vecherniy.com/wall?id=596
# Error at http://www.vecherniy.com/wall?id=597
# Error at http://www.vecherniy.com/wall?id=598
# Error at http://www.vecherniy.com/wall?id=599
# Error at http://www.vecherniy.com/wall?id=600
# Error at http://www.vecherniy.com/wall?id=601
# Error at http://www.vecherniy.com/wall?id=602
# Error at http://www.vecherniy.com/wall?id=603
# Error at http://www.vecherniy.com/wall?id=604
# Error at http://www.vecherniy.com/wall?id=605
# Error at http://www.vecherniy.com/wall?id=606
# Error at http://www.vecherniy.com/wall?id=607
# Error at http://www.vecherniy.com/wall?id=608
# Error at http://www.vecherniy.com/wall?id=610
# Error at http://www.vecherniy.com/wall?id=618
# Error at http://www.vecherniy.com/wall?id=621
# Error at http://www.vecherniy.com/wall?id=622
# Error at http://www.vecherniy.com/wall?id=623
# Error at http://www.vecherniy.com/wall?id=624
# Error at http://www.vecherniy.com/wall?id=625
# Error at http://www.vecherniy.com/wall?id=626
# Error at http://www.vecherniy.com/wall?id=629
# Error at http://www.vecherniy.com/wall?id=630
# Error at http://www.vecherniy.com/wall?id=631
# Error at http://www.vecherniy.com/wall?id=632
# Error at http://www.vecherniy.com/wall?id=633
# Error at http://www.vecherniy.com/wall?id=634
# Error at http://www.vecherniy.com/wall?id=635
# Error at http://www.vecherniy.com/wall?id=636
# Error at http://www.vecherniy.com/wall?id=637
# Error at http://www.vecherniy.com/wall?id=638
# Error at http://www.vecherniy.com/wall?id=639
# Error at http://www.vecherniy.com/wall?id=640
# Error at http://www.vecherniy.com/wall?id=641
# Error at http://www.vecherniy.com/wall?id=642
# Error at http://www.vecherniy.com/wall?id=643
# Error at http://www.vecherniy.com/wall?id=644
# Error at http://www.vecherniy.com/wall?id=645
# Error at http://www.vecherniy.com/wall?id=646
# Error at http://www.vecherniy.com/wall?id=647
# Error at http://www.vecherniy.com/wall?id=648
# Error at http://www.vecherniy.com/wall?id=649
# Error at http://www.vecherniy.com/wall?id=650
# Error at http://www.vecherniy.com/wall?id=651
# Error at http://www.vecherniy.com/wall?id=652
# Error at http://www.vecherniy.com/wall?id=653
# Error at http://www.vecherniy.com/wall?id=654
# Error at http://www.vecherniy.com/wall?id=727
# Error at http://www.vecherniy.com/wall?id=843
# Error at http://www.vecherniy.com/wall?id=878
# Error at http://www.vecherniy.com/wall?id=998
# Error at http://www.vecherniy.com/wall?id=1002
# Error at http://www.vecherniy.com/wall?id=1003
# Error at http://www.vecherniy.com/wall?id=1092
# Error at http://www.vecherniy.com/wall?id=1094
# Error at http://www.vecherniy.com/wall?id=1098
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-c35e3358b36c> in <module>
#       7
#       8 if __name__ == '__main__':
# ----> 9     main()
#
# <ipython-input-26-c35e3358b36c> in main()
#       1 def main():
# ----> 2     a = enum_art(crowler())
#       3     meta_csv(plain_folders(a))
#       4     mystemization(
#       5         r'Y\mystem-xml', a, '.xml', '--format xml ')
#
# <ipython-input-21-7db2744b6c64> in enum_art(bigD)
#       3
#       4 def enum_art(bigD):
# ----> 5     y = bigD[1]['year']
#       6     m = bigD[1]['month']
#       7     i = 0
#
# KeyError: 1
